# %%
import sys
sys.path.append('/home/momo/anaconda3/lib/python3.8/site-packages')
from itables import init_notebook_mode
from itables.sample_dfs import get_countries
from itables import init_notebook_mode, show
import pandas as pd
import itables.options as opt

opt.lengthMenu = [10]
df = pd.read_csv("NG21_weighted_bysite_EPI.csv")  
show(df)
# Out:
# WARNING:itables.downsample:showing 603x8 of 1206x8 as nbytes=77184>65536=maxBytes. See https://mwouts.github.io/itables/downsampling.html
# <table id="bb8d2e2d-4beb-450b-a940-fd047ba7a75a" class="display"style="max-width:100%"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SITE</th>
#       <th>GENE</th>
#       <th>G_annotation</th>
#       <th>SNP</th>
#       <th>Mutation</th>
#       <th>WildType</th>
#       <th>VAF</th>
#       <th>Total</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [[0, "Abia", "DHFR", "A16V", "A16", 0.0, 24.0, "0.0%", 24.0], [1, "Abia", "DHFR", "C59R", "59R", 24.0, 0.0, "96.4%", 24.0], [2, "Abia", "DHFR", "I164L", "I164", 0.0, 24.0, "0.0%", 24.0], [3, "Abia", "DHFR", "N51I", "51I", 24.0, 0.0, "96.35%", 24.0], [4, "Abia", "DHFR", "S108N", "108N", 24.0, 0.0, "99.91%", 24.0], [5, "Abia", "DHPS", "A437G", "437G", 23.0, 0.0, "99.37%", 23.0], [6, "Abia", "DHPS", "A581G", "581G", 22.0, 1.0, "87.31%", 23.0], [7, "Abia", "DHPS", "A613S", "613S", 23.0, 0.0, "97.72%", 23.0], [8, "Abia", "DHPS", "K540E", "K540", 0.0, 23.0, "0.0%", 23.0], [9, "Abia", "DHPS", "S436A", "436A", 23.0, 0.0, "98.02%", 23.0], [10, "Abia", "K13", "A481V", "A481", 0.0, 24.0, "0.0%", 24.0], [11, "Abia", "K13", "A578S", "A578", 0.0, 24.0, "0.0%", 24.0], [12, "Abia", "K13", "A675V", "A675", 0.0, 24.0, "0.0%", 24.0], [13, "Abia", "K13", "C469F", "C469", 0.0, 24.0, "0.0%", 24.0], [14, "Abia", "K13", "C469Y", "C469", 0.0, 24.0, "0.0%", 24.0], [15, "Abia", "K13", "C580Y", "C580", 0.0, 24.0, "0.0%", 24.0], [16, "Abia", "K13", "D584V", "D584", 0.0, 24.0, "0.0%", 24.0], [17, "Abia", "K13", "F446I", "F446", 0.0, 24.0, "0.0%", 24.0], [18, "Abia", "K13", "G449A", "G449", 0.0, 24.0, "0.0%", 24.0], [19, "Abia", "K13", "G538V", "G538", 0.0, 24.0, "0.0%", 24.0], [20, "Abia", "K13", "I543T", "I543", 0.0, 24.0, "0.0%", 24.0], [21, "Abia", "K13", "M476I", "M476", 0.0, 24.0, "0.0%", 24.0], [22, "Abia", "K13", "N458Y", "N458", 0.0, 24.0, "0.0%", 24.0], [23, "Abia", "K13", "N537I", "N537", 0.0, 24.0, "0.0%", 24.0], [24, "Abia", "K13", "P441L", "P441", 0.0, 24.0, "0.0%", 24.0], [25, "Abia", "K13", "P527H", "P527", 0.0, 24.0, "0.0%", 24.0], [26, "Abia", "K13", "P553L", "P553", 0.0, 24.0, "0.0%", 24.0], [27, "Abia", "K13", "P574L", "P574", 0.0, 24.0, "0.0%", 24.0], [28, "Abia", "K13", "R515K", "R515", 0.0, 24.0, "0.0%", 24.0], [29, "Abia", "K13", "R539T", "R539", 0.0, 24.0, "0.0%", 24.0], [30, "Abia", "K13", "R561H", "R561", 0.0, 24.0, "0.0%", 24.0], [31, "Abia", "K13", "R622I", "R622", 0.0, 24.0, "0.0%", 24.0], [32, "Abia", "K13", "V568G", "V568", 0.0, 24.0, "0.0%", 24.0], [33, "Abia", "K13", "Y493H", "Y493", 0.0, 24.0, "0.0%", 24.0], [34, "Adamawa", "DHFR", "A16V", "A16", 0.0, 28.0, "0.0%", 28.0], [35, "Adamawa", "DHFR", "C59R", "59R", 28.0, 0.0, "97.55%", 28.0], [36, "Adamawa", "DHFR", "I164L", "I164", 0.0, 28.0, "0.0%", 28.0], [37, "Adamawa", "DHFR", "N51I", "51I", 28.0, 0.0, "94.6%", 28.0], [38, "Adamawa", "DHFR", "S108N", "108N", 28.0, 0.0, "99.75%", 28.0], [39, "Adamawa", "DHPS", "A437G", "437G", 32.0, 0.0, "84.94%", 32.0], [40, "Adamawa", "DHPS", "A581G", "581G", 28.0, 4.0, "32.16%", 32.0], [41, "Adamawa", "DHPS", "A613S", "613S", 30.0, 2.0, "40.23%", 32.0], [42, "Adamawa", "DHPS", "K540E", "K540", 0.0, 32.0, "0.0%", 32.0], [43, "Adamawa", "DHPS", "S436A", "436A", 28.0, 4.0, "63.4%", 34.0], [44, "Adamawa", "DHPS", "S436F", "436F", 2.0, 4.0, "2.18%", 34.0], [45, "Adamawa", "K13", "A481V", "A481", 0.0, 29.0, "0.0%", 29.0], [46, "Adamawa", "K13", "A578S", "A578", 0.0, 29.0, "0.0%", 29.0], [47, "Adamawa", "K13", "A675V", "A675", 0.0, 29.0, "0.0%", 29.0], [48, "Adamawa", "K13", "C469F", "C469", 0.0, 29.0, "0.0%", 29.0], [49, "Adamawa", "K13", "C469Y", "C469", 0.0, 29.0, "0.0%", 29.0], [50, "Adamawa", "K13", "C580Y", "C580", 0.0, 29.0, "0.0%", 29.0], [51, "Adamawa", "K13", "D584V", "D584", 0.0, 29.0, "0.0%", 29.0], [52, "Adamawa", "K13", "F446I", "F446", 0.0, 29.0, "0.0%", 29.0], [53, "Adamawa", "K13", "G449A", "G449", 0.0, 29.0, "0.0%", 29.0], [54, "Adamawa", "K13", "G538V", "G538", 0.0, 29.0, "0.0%", 29.0], [55, "Adamawa", "K13", "I543T", "I543", 0.0, 29.0, "0.0%", 29.0], [56, "Adamawa", "K13", "M476I", "M476", 0.0, 29.0, "0.0%", 29.0], [57, "Adamawa", "K13", "N458Y", "N458", 0.0, 29.0, "0.0%", 29.0], [58, "Adamawa", "K13", "N537I", "N537", 0.0, 29.0, "0.0%", 29.0], [59, "Adamawa", "K13", "P441L", "P441", 0.0, 29.0, "0.0%", 29.0], [60, "Adamawa", "K13", "P527H", "P527", 0.0, 29.0, "0.0%", 29.0], [61, "Adamawa", "K13", "P553L", "P ...

# %%
df = pd.read_csv("Tab_Table_SNP_Total1.csv")  
show(df)
# Out:
# <table id="9541066e-c729-4eb9-9bb8-d6afffebb3de" class="display"style="max-width:100%"><thead>
#     <tr style="text-align: right;">
#
#       <th>Gene+SNP</th>
#       <th>Wildtype: AF=0%</th>
#       <th>Minor: AF &lt; 50%</th>
#       <th>Major: AF &gt;= 50%</th>
#       <th>Samplesize</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [["DHFR:S108N", 0.004, 0.979, 0.016, "N=910.0"], ["DHFR:C59R", 0.011, 0.954, 0.035, "N=908.0"], ["K13:I543T", 0.999, 0.0, 0.001, "N=935.0"], ["DHPS:S436A", 0.061, 0.71, 0.229, "N=839.0"], ["DHPS:A437G", 0.014, 0.93, 0.056, "N=839.0"], ["DHPS:A581G", 0.304, 0.383, 0.312, "N=848.0"], ["DHPS:A613S", 0.152, 0.491, 0.357, "N=848.0"], ["DHFR:N51I", 0.013, 0.932, 0.055, "N=908.0"], ["K13:A578S", 0.98, 0.006, 0.014, "N=935.0"], ["K13:P574L", 1.0, 0.0, 0.0, "N=935.0"], ["DHFR:A16V", 1.0, 0.0, 0.0, "N=890.0"], ["K13:P441L", 1.0, 0.0, 0.0, "N=935.0"], ["K13:F446I", 1.0, 0.0, 0.0, "N=935.0"], ["K13:C580Y", 1.0, 0.0, 0.0, "N=935.0"], ["K13:C469F", 1.0, 0.0, 0.0, "N=935.0"], ["K13:C469Y", 1.0, 0.0, 0.0, "N=935.0"], ["K13:M476I", 1.0, 0.0, 0.0, "N=935.0"], ["K13:A481V", 1.0, 0.0, 0.0, "N=935.0"], ["DHPS:K540E", 1.0, 0.0, 0.0, "N=838.0"], ["K13:D584V", 1.0, 0.0, 0.0, "N=935.0"], ["K13:P553L", 1.0, 0.0, 0.0, "N=934.0"], ["K13:A675V", 1.0, 0.0, 0.0, "N=930.0"], ["K13:N537I", 1.0, 0.0, 0.0, "N=935.0"], ["K13:G538V", 1.0, 0.0, 0.0, "N=935.0"], ["K13:N458Y", 1.0, 0.0, 0.0, "N=935.0"], ["K13:R561H", 1.0, 0.0, 0.0, "N=934.0"], ["K13:V568G", 1.0, 0.0, 0.0, "N=934.0"], ["K13:P527H", 1.0, 0.0, 0.0, "N=935.0"], ["K13:Y493H", 1.0, 0.0, 0.0, "N=935.0"], ["K13:R622I", 1.0, 0.0, 0.0, "N=935.0"], ["K13:R539T", 1.0, 0.0, 0.0, "N=935.0"], ["DHFR:I164L", 1.0, 0.0, 0.0, "N=903.0"], ["K13:R515K", 1.0, 0.0, 0.0, "N=935.0"], ["K13:G449A", 1.0, 0.0, 0.0, "N=935.0"]];
#
#     if (typeof require === 'undefined') {
#         // TODO: This should become the default (use a simple import)
#         // when the ESM version works independently of whether
#         // require.js is there or not, see
#         // https://datatables.net/forums/discussion/69066/esm-es6-module-support?
#         const {default: $} = await import("https://esm.sh/jquery@3.5.0");
#         const {default: initDataTables} = await import("https://esm.sh/datatables.net@1.11.3?deps=jquery@3.5.0");
#
#         initDataTables();
#
#         // Define the dt_args
#         let dt_args = {"lengthMenu": [10]};
#         dt_args["data"] = data;
#
#         // Display the table
#         $(document).ready(function () {
#             $('#9541066e-c729-4eb9-9bb8-d6afffebb3de').DataTable(dt_args);
#         });
#     } else {
#         require(["jquery", "datatables"], ($, datatables) => {
#                 // Define the dt_args
#                 let dt_args = {"lengthMenu": [10]};
#                 dt_args["data"] = data;
#
#                 // Display the table
#                 $(document).ready(function () {
#                     $('#9541066e-c729-4eb9-9bb8-d6afffebb3de').DataTable(dt_args);
#                 });
#             }
#         )
#     }
# </script>
